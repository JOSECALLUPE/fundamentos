# %% [markdown]
# <a href="https://colab.research.google.com/github/JOSECALLUPE/fundamentos/blob/chinito-chi/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Descuento según monto total de compra

# Solicitar monto al usuario
monto = float(input("🛍️ Ingrese el monto total de su compra (S/): "))

# Determinar descuento
if monto > 500:
    descuento = 0.20
elif 200 <= monto <= 500:
    descuento = 0.10
else:
    descuento = 0.0

# Cálculo del monto con descuento
monto_descuento = monto * descuento
monto_final = monto - monto_descuento

# Mostrar resultados
print("\n📋 RESUMEN DE COMPRA")
print(f"Monto original     : S/{monto:.2f}")
print(f"Descuento aplicado : {descuento*100:.0f}%")
print(f"Descuento en soles : S/{monto_descuento:.2f}")
print(f"Total a pagar      : S/{monto_final:.2f}")
# Out:
# 🛍️ Ingrese el monto total de su compra (S/): 2
#
# 📋 RESUMEN DE COMPRA
# Monto original     : S/2.00
# Descuento aplicado : 0%
# Descuento en soles : S/0.00
# Total a pagar      : S/2.00
